# %%
import pandas as pd
import os

os.chdir('/home/aicenter/Dev/dementia-gait-pattern')

gait_cycle = pd.read_csv('data/gait_cycle.csv')
gait_cycle
# Out:
#      Subject Context                   Name       Value      Units  \
# 0   01Jirada    Left                Cadence  118.460000  steps/min
# 1   01Jirada    Left          Walking Speed    1.133960        m/s
# 2   01Jirada    Left            Stride Time    1.013000          s
# 3   01Jirada    Left              Step Time    0.521000          s
# 4   01Jirada    Left      Opposite Foot Off   12.142200          %
# 5   01Jirada    Left  Opposite Foot Contact   48.568600          %
# 6   01Jirada    Left               Foot Off   62.487700          %
# 7   01Jirada    Left         Single Support   36.426500          %
# 8   01Jirada    Left         Double Support   26.061200          %
# 9   01Jirada    Left          Stride Length  114.870000         cm
# 10  01Jirada    Left            Step Length   58.081400         cm
# 11  01Jirada    Left             Step Width   17.791300         cm
# 12  01Jirada    Left             Limp Index    0.982920        NaN
# ...

# %%
gait_cycle = gait_cycle.drop(columns=['Description'])
gait_cycle
# Out:
#      Subject Context                   Name       Value      Units
# 0   01Jirada    Left                Cadence  118.460000  steps/min
# 1   01Jirada    Left          Walking Speed    1.133960        m/s
# 2   01Jirada    Left            Stride Time    1.013000          s
# 3   01Jirada    Left              Step Time    0.521000          s
# 4   01Jirada    Left      Opposite Foot Off   12.142200          %
# 5   01Jirada    Left  Opposite Foot Contact   48.568600          %
# 6   01Jirada    Left               Foot Off   62.487700          %
# 7   01Jirada    Left         Single Support   36.426500          %
# 8   01Jirada    Left         Double Support   26.061200          %
# 9   01Jirada    Left          Stride Length  114.870000         cm
# 10  01Jirada    Left            Step Length   58.081400         cm
# 11  01Jirada    Left             Step Width   17.791300         cm
# 12  01Jirada    Left             Limp Index    0.982920        NaN
# ...

# %%
events = pd.read_excel('data/events.xlsx')
events
# Out:
#      Subject Context         Name  Time (s)  \
# 0   01Jirada    Left     Foot Off     4.060
# 1   01Jirada    Left  Foot Strike     4.417
# 2   01Jirada    Left     Foot Off     5.050
# 3   01Jirada    Left  Foot Strike     5.430
# 4   01Jirada    Left     Foot Off     6.060
# 5   01Jirada    Left  Foot Strike     6.470
# 6   01Jirada   Right  Foot Strike     3.860
# 7   01Jirada   Right     Foot Off     4.540
# 8   01Jirada   Right  Foot Strike     4.909
# 9   01Jirada   Right     Foot Off     5.549
# 10  01Jirada   Right  Foot Strike     5.940
#
#                                 Description
# 0     The instant the toe leaves the ground
# 1   The instant the heel strikes the ground
# 2     The instant the toe leaves the ground
# 3   The instant the heel strikes the ground
# 4     The instant the toe leaves the ground
# 5   The instant the heel strikes the ground
# 6   The instant the heel strikes the ground
# 7     The instant the toe leaves the ground
# ...

# %%
print('# Gait Cycle Parameters')
print('')
print(gait_cycle.to_markdown())
print('\n')
print('# Events\n')
print(events.to_markdown())
# Out:
# # Gait Cycle Parameters
#
# |    | Subject   | Context   | Name                  |      Value | Units     |
# |---:|:----------|:----------|:----------------------|-----------:|:----------|
# |  0 | 01Jirada  | Left      | Cadence               | 118.46     | steps/min |
# |  1 | 01Jirada  | Left      | Walking Speed         |   1.13396  | m/s       |
# |  2 | 01Jirada  | Left      | Stride Time           |   1.013    | s         |
# |  3 | 01Jirada  | Left      | Step Time             |   0.521    | s         |
# |  4 | 01Jirada  | Left      | Opposite Foot Off     |  12.1422   | %         |
# |  5 | 01Jirada  | Left      | Opposite Foot Contact |  48.5686   | %         |
# |  6 | 01Jirada  | Left      | Foot Off              |  62.4877   | %         |
# |  7 | 01Jirada  | Left      | Single Support        |  36.4265   | %         |
# |  8 | 01Jirada  | Left      | Double Support        |  26.0612   | %         |
# ...

# %%
print(gait_cycle['Name'])
# Out:
# 0                   Cadence
# 1             Walking Speed
# 2               Stride Time
# 3                 Step Time
# 4         Opposite Foot Off
# 5     Opposite Foot Contact
# 6                  Foot Off
# 7            Single Support
# 8            Double Support
# 9             Stride Length
# 10              Step Length
# 11               Step Width
# 12               Limp Index
# 13                  Cadence
# 14            Walking Speed
# 15              Stride Time
# 16                Step Time
# 17        Opposite Foot Off
# 18    Opposite Foot Contact
# 19                 Foot Off
# 20           Single Support
# 21           Double Support
# 22            Stride Length
# 23              Step Length
# 24               Step Width
# 25               Limp Index
# Name: Name, dtype: object
