# %%
r1_c3 = 4901-4772
r1_c3
# Out:
# 129

# %%
r2_c3 = 5360 - 5245
r2_c3
# Out:
# 5360

# %%
r3_c3 = 5914 - 5795
r3_c3
# Out:
# 119

# %%
r4_c3 = 6394 -6270
r4_c3
# Out:
# 124

# %%
r5_c3 = -119-6697
r5_c3
# Out:
# -6816

# %%
r6_c3 = -85-7497
r6_c3
# Out:
# -7582

# %%
r7_c3 = 8120-8021
r7_c3
# Out:
# 99

# %%
r9_c3 = 8543-8421
r9_c3
# Out:
# 122

# %%
r10_c3 = 8974-8846
r10_c3
# Out:
# 128

# %%
r11_c3 = 9378-9271
r11_c3
# Out:
# 107

# %%
r12_c3 = 10129-9996
r12_c3
# Out:
# 133

# %%
r14_c3 = 10681-10546
r14_c3
# Out:
# 135

# %%
r16_c3 = 11860-11696
r16_c3
# Out:
# -11860

# %%
r18_c3 = 12370-12221
r18_c3
# Out:
# 149

# %%
r19_c3 = 13549-13394
r19_c3
# Out:
# 155

# %%
r20_c3 = 14138-13967
r20_c3
# Out:
# 171

# %%
r21_c3 = 14710-14543
r21_c3
# Out:
# 167

# %%
r22_c3 = 14710-14543
r22_c3
# Out:
# 167

# %%
r23_c3 = 15253-15093
r23_c3
# Out:
# 160

# %%
r25_c3 = 15891-15743
r25_c3
# Out:
# 148

# %%
r26_c3 = 19314-19016
r26_c3
# Out:
# 298

# %%
r27_c3 = 28334-27988
r27_c3
# Out:
# -28334

# %%
r28_c3=29231-28909
r28_c3
# Out:
# 322

# %%
r29_c3 = -324-29409
r29_c3
# Out:
# -29733

# %%
r30_c3 = 30483-30184
r30_c3
# Out:
# 299

# %%
r31_c3 = 31283-30984
r31_c3
# Out:
# -31283
