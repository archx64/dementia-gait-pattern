# %%
r14_c2 = 3939-3790
r14_c2

# r15 is same as r14
# Out:
# 149

# %%
r16_c2 = 4504-4340
r16_c2
# Out:
# 164

# %%
# r17 is the same as r18

r18_c2 = 5014 - 4865
r18_c2
# Out:
# 149

# %%
r19_c2 = 6195 - 6040
r19_c2
# Out:
# 155

# %%
r20_c2 = 6786 - 6615 
r20_c2
# Out:
# 171

# %%
r21_c2 = 7358 - 7191
r21_c2
# Out:
# 167

# %%
r23_c2 = 7901 - 7741
r23_c2
# Out:
# 160

# %%
r25_c2 = 8539 - 8391
r25_c2
# Out:
# 148

# %%
r26_c2 = 11964 - 11666
r26_c2
# Out:
# 298

# %%
r27_c2 = 20989 - 20643
r27_c2
# Out:
# 346

# %%
r28_c2 = 21890- 21568
r28_c2
# Out:
# 322

# %%
r29_c2 = 22395 - 22071
r29_c2
# Out:
# 324

# %%
r30_c2 = 23145 - 22846
r30_c2
# Out:
# 299

# %%
r31_c2 = 23945 - 23646
r31_c2
# Out:
# 299
